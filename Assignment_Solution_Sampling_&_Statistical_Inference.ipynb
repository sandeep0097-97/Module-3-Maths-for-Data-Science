# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep0097-97/Module-3-Maths-for-Data-Science/blob/main/Assignment_Solution_Sampling_%26_Statistical_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<u> Problem 1

# %% [markdown]
# ![Screenshot 2020-11-30 at 5.25.55 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2020-12-01 at 6.54.24 PM.png](data:image/png;base64,...)

# %% [markdown]
# #<u> Problem 2 </u>

# %% [markdown]
# ![Screenshot 2020-11-30 at 5.27.19 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2020-12-01 at 6.56.20 PM.png](data:image/png;base64,...)

# %% [markdown]
# # <u>Problem 3

# %% [markdown]
# ![Screenshot 2020-11-30 at 5.28.32 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2020-12-01 at 7.02.36 PM.png](data:image/png;base64,...)

# %%
from scipy.stats import norm

# Answer is
norm.cdf(1.789) - norm.cdf(-1.789)
# Out:
# 0.9263851844449822

# %% [markdown]
# ![Screenshot 2020-12-01 at 7.02.47 PM.png](data:image/png;base64,...)

# %%
from scipy.stats import chi2

# Answer is
1 - chi2.cdf(11.13, 4)
# Out:
# 0.025141196279531708

# %% [markdown]
# # <u>Problem 4

# %% [markdown]
# ![Screenshot 2020-11-30 at 5.29.19 PM.png](data:image/png;base64,...)

# %% [markdown]
# The distribution will be t with n-1=5-1=4 degrees of freedom.

# %% [markdown]
# ![Screenshot 2020-12-01 at 6.57.29 PM.png](data:image/png;base64,...)

# %%
from scipy.stats import t

# %%
# We need to find P(t_4 > 1.533)

1 - t.cdf(1.533, 4)
# Out:
# 0.10002435691404998
