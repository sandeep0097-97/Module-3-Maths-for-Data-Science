# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep0097-97/Module-3-Maths-for-Data-Science/blob/main/Assignment_Solution_Confidence_Intervals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<u> Problem 1

# %% [markdown]
# ![Screenshot 2020-12-01 at 5.49.48 PM.png](data:image/png;base64,...)

# %% [markdown]
# #<u> Solution 1

# %% [markdown]
# ![Screenshot 2020-12-03 at 1.16.47 PM.png](data:image/png;base64,...)

# %% [markdown]
# #<u> Problem 2 </u>

# %% [markdown]
# ![Screenshot 2020-12-01 at 6.10.18 PM.png](data:image/png;base64,...)

# %% [markdown]
# #<u> Solution 2

# %% [markdown]
# ![Screenshot 2020-12-03 at 1.20.30 PM.png](data:image/png;base64,...)
