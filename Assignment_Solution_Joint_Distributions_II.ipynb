# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep0097-97/Module-3-Maths-for-Data-Science/blob/main/Assignment_Solution_Joint_Distributions_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<u> Problem 1

# %% [markdown]
# ![Joint_Dist4.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Q1a.jpg](data:image/jpeg;base64,...)
#
# ![Q1b.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #<u> Problem 2 </u>

# %% [markdown]
# ![Joint_Dist5.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Q2a.jpg](data:image/jpeg;base64,...)
#
# ![Q2b.jpg](data:image/jpeg;base64,...)
#
# ![Q2c.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # <u>Problem 3

# %% [markdown]
# ![Joint_Dist6.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Q3.jpg](data:image/jpeg;base64,...)
